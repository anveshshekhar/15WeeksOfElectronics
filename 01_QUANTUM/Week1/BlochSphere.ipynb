# %%
from qiskit import QuantumCircuit
from qiskit.visualization import plot_bloch_multivector
from math import pi

# Initialize Quantum Circuits and Display Initial Bloch-Vectors
qc1 = QuantumCircuit(4)
qc2 = QuantumCircuit(3)
display(plot_bloch_multivector(Statevector.from_instruction(qc1)))

# Implement Gates per Qubit: H on Qubit 0; H then S on Qubit 1; H then T on Qubit 2; Y on Qubit 3
qc1.h(0)
qc1.h(1)
qc1.s(1)
qc1.h(2)
qc1.t(2)
qc1.y(3)
display(plot_bloch_multivector(Statevector.from_instruction(qc1)))
display(qc1.draw(output="mpl"))


# Display Initial State for Second Circuit
display(plot_bloch_multivector(Statevector.from_instruction(qc2)))

# Apply Parameterized Rotation Gates (Rx, Ry, Rz) and Visualize Phase/Amplitude Changes
qc2.rx(-pi/3,0)
qc2.ry(pi/3,1)
qc2.h(2)
qc2.rz(pi/3,2)
display(plot_bloch_multivector(Statevector.from_instruction(qc2)))
display(qc2.draw(output="mpl"))
